# %% [markdown]
# # Vizualize the data

# %%
# import pandas as pd
from glob import glob

# %%
glob("../data/LibriCount/*.json")
# Out:
# ['../data/LibriCount/0_005682.json',
#  '../data/LibriCount/0_006e22.json',
#  '../data/LibriCount/0_012ba7.json',
#  '../data/LibriCount/0_0216c2.json',
#  '../data/LibriCount/0_022f96.json',
#  '../data/LibriCount/0_02acaa.json',
#  '../data/LibriCount/0_02dec3.json',
#  '../data/LibriCount/0_0428c5.json',
#  '../data/LibriCount/0_05f915.json',
#  '../data/LibriCount/0_0681fb.json',
#  '../data/LibriCount/0_06d6f4.json',
#  '../data/LibriCount/0_081d37.json',
#  '../data/LibriCount/0_0844de.json',
#  '../data/LibriCount/0_08a900.json',
#  '../data/LibriCount/0_08d611.json',
#  '../data/LibriCount/0_0909ff.json',
#  '../data/LibriCount/0_09f407.json',
#  '../data/LibriCount/0_0a6d52.json',
#  '../data/LibriCount/0_0b842f.json',
#  '../data/LibriCount/0_0b9156.json',
#  '../data/LibriCount/0_0c531b.json',
#  '../data/LibriCount/0_0c6985.json',
#  '../data/LibriCount/0_0c72bb.json',
#  '../data/LibriCount/0_0e0df0.json',
#  '../data/LibriCount/0_0eeda1.json',
# ...
